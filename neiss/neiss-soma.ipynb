# %%
# !ls
# Out:
# 2017 NEISS Data Highlights.pdf        NEISS.ipynb
# 2018-NEISS-CPSC-only-CodingManual.pdf neiss2017.tsv
# 2018ComparabilityTable.pdf            neiss_fmt.txt

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
# Drop to the command line, and say
# show me the first 5 rows of this file
# !head -n 5 neiss2017.tsv
# Out:
# "CPSC_Case_Number"	"Treatment_Date"	"Age"	"Sex"	"Race"	"Other_Race"	"Body_Part"	"Diagnosis"	"Other_Diagnosis"	"Disposition"	"Location"	"Fire_Involvement"	"Product_1"	"Product_2"	"Narrative_1"	"Narrative_2"	"Stratum"	"PSU"	"Weight"
# 170100733	01/01/2017	21	1	1		75	62		1	1	0	1207	0	21YOM WAS BOXING WITH FRIEND WHILE DRINKING AND GOT PUNCHED IN THE FACE	. BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXICATION	S	46	77.6641
# 170100734	01/01/2017	71	1	1		31	53		1	5	0	1807	0	71YOM FELL ON FLOOR IN BATHROOM. DX RIB CONTUSION		S	46	77.6641
# 170100735	01/01/2017	16	1	1		33	51		1	1	0	676	342	16YOM TRIPPED OVER A RUG AND FELL INTO A BURNING FIREPLACE	DX BURNS INVOLVING LESS THAN 10% OF BODY SURFACE, FOREARM	S	46	77.6641
# 170100737	01/01/2017	55	2	1		75	62		1	1	0	620	0	55YOF WAS STANDING ON A STEP STOOL AND LOST FOOTING AND FELL. DX CLOSED	HEAD INJURY	S	46	77.6641

# %%
# \t means 'the tab character'
# \n means 'a new line'
# sep= means "this is what separated our stuff"
# encoding= says "this is the encoding I want to use"
# since unicode/utf-8 doesn't work, we'll try latin-1
df = pd.read_csv("neiss2017.tsv", sep='\t', encoding='latin-1', na_values=[0, "UNKNOWN"])
df.head(2)
# Out:
# /Users/jonathansoma/.pyenv/versions/3.6.7/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   CPSC_Case_Number Treatment_Date Age  Sex  Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21  1.0   1.0        NaN       75.0
# 1        170100734     01/01/2017  71  1.0   1.0        NaN       31.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               NaN
# 1       53.0             NaN          1.0       5.0               NaN
#
#    Product_1  Product_2                                        Narrative_1  \
# 0     1207.0        NaN  21YOM WAS BOXING WITH FRIEND WHILE DRINKING AN...
# 1     1807.0        NaN  71YOM FELL ON FLOOR IN BATHROOM. DX RIB CONTUSION
#
#                                          Narrative_2 Stratum   PSU   Weight
# 0  . BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXIC...       S  46.0  77.6641
# 1                                                NaN       S  46.0  77.6641

# %% [markdown]
# How many rows (and columns) do we have?

# %%
df.shape
# Out:
# (386907, 19)

# %%
df.tail(2)
# Out:
#        CPSC_Case_Number Treatment_Date  Age  Sex  Race Other_Race  Body_Part  \
# 386905        180309765     12/31/2017  202  1.0   1.0        NaN       75.0
# 386906        180309766     12/31/2017    2  2.0   1.0        NaN       85.0
#
#         Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 386905       57.0             NaN          4.0       1.0               NaN
# 386906       68.0             NaN          4.0       1.0               NaN
#
#         Product_1  Product_2  \
# 386905     1842.0        NaN
# 386906     1931.0        NaN
#
#                                               Narrative_1 Narrative_2 Stratum  \
# 386905  2MO M DAD FELL ON STAIRS WHILE HOLDING BABY;DX...         NaN       C
# 386906  2YR F GOT INTO DAD'S ***;DX ACCIDENTAL DRUG IN...         NaN       C
#
#          PSU  Weight
# 386905  20.0   4.757
# 386906  20.0   4.757

# %%
df.dtypes
# Out:
# CPSC_Case_Number     object
# Treatment_Date       object
# Age                  object
# Sex                 float64
# Race                float64
# Other_Race           object
# Body_Part           float64
# Diagnosis           float64
# Other_Diagnosis      object
# Disposition         float64
# Location            float64
# Fire_Involvement    float64
# Product_1           float64
# Product_2           float64
# Narrative_1          object
# Narrative_2          object
# Stratum              object
# PSU                 float64
# Weight              float64
# dtype: object

# %%
df.Sex.value_counts()
# Out:
# 1.0    208695
# 2.0    178203
# 8.0         1
# Name: Sex, dtype: int64

# %%
df.Sex.head(5)
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    2.0
# 4    2.0
# Name: Sex, dtype: float64

# %%
# 1 - Male
# 2 - Female
# 0 - Not recorded
# 8 - ???????

# When we make a change, we need to do df['column'] = ....
# or else it won't update the column

df['Sex'] = df.Sex.replace({
    1: 'Male',
    2: 'Female',
    0: 'Not recorded'
})

# %%
df.head()
# Out:
#   CPSC_Case_Number Treatment_Date Age     Sex  Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21    Male   1.0        NaN       75.0
# 1        170100734     01/01/2017  71    Male   1.0        NaN       31.0
# 2        170100735     01/01/2017  16    Male   1.0        NaN       33.0
# 3        170100737     01/01/2017  55  Female   1.0        NaN       75.0
# 4        170100740     01/01/2017  86  Female   1.0        NaN       79.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               NaN
# 1       53.0             NaN          1.0       5.0               NaN
# 2       51.0             NaN          1.0       1.0               NaN
# 3       62.0             NaN          1.0       1.0               NaN
# 4       58.0             NaN          1.0       1.0               NaN
#
#    Product_1  Product_2                                        Narrative_1  \
# 0     1207.0        NaN  21YOM WAS BOXING WITH FRIEND WHILE DRINKING AN...
# 1     1807.0        NaN  71YOM FELL ON FLOOR IN BATHROOM. DX RIB CONTUSION
# 2      676.0      342.0  16YOM TRIPPED OVER A RUG AND FELL INTO A BURNI...
# 3      620.0        NaN  55YOF WAS STANDING ON A STEP STOOL AND LOST FO...
# 4     1646.0     4056.0  86YOF GOT TANGLED IN COAT AND FELL BACKWARD ST...
#
#                                          Narrative_2 Stratum   PSU   Weight
# 0  . BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXIC...       S  46.0  77.6641
# 1                                                NaN       S  46.0  77.6641
# 2  DX BURNS INVOLVING LESS THAN 10% OF BODY SURFA...       S  46.0  77.6641
# 3                                        HEAD INJURY       S  46.0  77.6641
# 4          H. DX HEMATOMA OF SOFT TISSUE, LEFT FLANK       S  46.0  77.6641

# %%
df.Sex.value_counts()
# Out:
# Male      208695
# Female    178203
# 8.0            1
# Name: Sex, dtype: int64

# %%
# Just show me the row where 'Sex' is 8
df[df.Sex == 8]
# Out:
#        CPSC_Case_Number Treatment_Date Age Sex   Race Other_Race  Body_Part  \
# 160878      ;CONCUSSION            NaN   C   8  4.757        NaN        NaN
#
#         Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 160878        NaN             NaN          NaN       NaN               NaN
#
#         Product_1  Product_2 Narrative_1 Narrative_2 Stratum  PSU  Weight
# 160878        NaN        NaN         NaN         NaN     NaN  NaN     NaN

# %%
# Oh weird, we're missing a treatment date and other stuff....
df.head(3)
# Out:
#   CPSC_Case_Number Treatment_Date Age   Sex  Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21  Male   1.0        NaN       75.0
# 1        170100734     01/01/2017  71  Male   1.0        NaN       31.0
# 2        170100735     01/01/2017  16  Male   1.0        NaN       33.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               NaN
# 1       53.0             NaN          1.0       5.0               NaN
# 2       51.0             NaN          1.0       1.0               NaN
#
#    Product_1  Product_2                                        Narrative_1  \
# 0     1207.0        NaN  21YOM WAS BOXING WITH FRIEND WHILE DRINKING AN...
# 1     1807.0        NaN  71YOM FELL ON FLOOR IN BATHROOM. DX RIB CONTUSION
# 2      676.0      342.0  16YOM TRIPPED OVER A RUG AND FELL INTO A BURNI...
#
#                                          Narrative_2 Stratum   PSU   Weight
# 0  . BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXIC...       S  46.0  77.6641
# 1                                                NaN       S  46.0  77.6641
# 2  DX BURNS INVOLVING LESS THAN 10% OF BODY SURFA...       S  46.0  77.6641

# %% [markdown]
# # Dealing with missing data

# %%
# Is treatment date empty???
# .isna() or .isnull()
df.Treatment_Date.isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 386877    False
# 386878    False
# 386879    False
# 386880    False
# 386881    False
# 386882    False
# 386883    False
# 386884    False
# 386885    False
# 386886    False
# 386887    False
# 386888    False
# 386889    False
# 386890    False
# 386891    False
# 386892    False
# 386893    False
# 386894    False
# 386895    False
# 386896    False
# 386897    False
# 386898    False
# 386899    False
# 386900    False
# 386901    False
# 386902    False
# 386903    False
# 386904    False
# 386905    False
# 386906    False
# Name: Treatment_Date, Length: 386907, dtype: bool

# %%
df[df.Treatment_Date.isna()]
# Out:
#        CPSC_Case_Number Treatment_Date Age Sex   Race Other_Race  Body_Part  \
# 160878      ;CONCUSSION            NaN   C   8  4.757        NaN        NaN
#
#         Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 160878        NaN             NaN          NaN       NaN               NaN
#
#         Product_1  Product_2 Narrative_1 Narrative_2 Stratum  PSU  Weight
# 160878        NaN        NaN         NaN         NaN     NaN  NaN     NaN

# %%
# False is 0, True is 1
# So every time Treatment Date is missing, it adds 1
df.Treatment_Date.isna().sum()
# Out:
# 1

# %%
# Adds up all of the Trues as 1, False as 0
(df.Sex == 'Male').sum()
# Out:
# 208695

# %%
# Remove rows that are missing data in ONE (or more) specific columns
df = df.dropna(subset=['Treatment_Date'])

# %%
df[df.Treatment_Date.isna()]
# Out:
# Empty DataFrame
# Columns: [CPSC_Case_Number, Treatment_Date, Age, Sex, Race, Other_Race, Body_Part, Diagnosis, Other_Diagnosis, Disposition, Location, Fire_Involvement, Product_1, Product_2, Narrative_1, Narrative_2, Stratum, PSU, Weight]
# Index: []

# %% [markdown]
# # We got rid of Age being C, so let's look at it again

# %%
# Smallest age in the dataset
# Can't do this yet!
# df.Age.min()

# %%
df.dtypes
# Out:
# CPSC_Case_Number     object
# Treatment_Date       object
# Age                  object
# Sex                  object
# Race                float64
# Other_Race           object
# Body_Part           float64
# Diagnosis           float64
# Other_Diagnosis      object
# Disposition         float64
# Location            float64
# Fire_Involvement    float64
# Product_1           float64
# Product_2           float64
# Narrative_1          object
# Narrative_2          object
# Stratum              object
# PSU                 float64
# Weight              float64
# dtype: object

# %%
#int('5')
# PERMANENTLY change the Age into an integer
df['Age'] = df.Age.astype(float)

# %%
df.Age.min()
# Out:
# 2.0

# %%
df.Age.median()
# Out:
# 29.0

# %%
df.Age.describe()
# Out:
# count    386886.000000
# mean         44.370753
# std          49.561221
# min           2.000000
# 25%          12.000000
# 50%          29.000000
# 75%          60.000000
# max         223.000000
# Name: Age, dtype: float64

# %%
df.Age.hist(bins=50)

# %%
# Count up all of the times age is greater than 200
# False counts as 0
# True counts as 1
# so you can do .sum() to add up all of the 1's
(df.Age >= 200).sum()
# Out:
# 22818

# %%
# You COULD run this to get of those tiny tiny people,
# and only keep people under 200 years old
df = df[df.Age < 200]

# %%
# How many people are still over 200?
(df.Age >= 200).sum()
# Out:
# 0

# %%
df.Age.hist(bins=25)

# %%
df.head(2)
# Out:
#   CPSC_Case_Number Treatment_Date   Age   Sex  Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21.0  Male   1.0        NaN       75.0
# 1        170100734     01/01/2017  71.0  Male   1.0        NaN       31.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               NaN
# 1       53.0             NaN          1.0       5.0               NaN
#
#    Product_1  Product_2                                        Narrative_1  \
# 0     1207.0        NaN  21YOM WAS BOXING WITH FRIEND WHILE DRINKING AN...
# 1     1807.0        NaN  71YOM FELL ON FLOOR IN BATHROOM. DX RIB CONTUSION
#
#                                          Narrative_2 Stratum   PSU   Weight
# 0  . BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXIC...       S  46.0  77.6641
# 1                                                NaN       S  46.0  77.6641

# %%
df.groupby('Sex').Age.median()
# Out:
# Sex
# Female    32.0
# Male      21.0
# Name: Age, dtype: float64

# %%
df.groupby('Sex').Age.hist(alpha=0.5, bins=25)
# Out:
# Sex
# Female    AxesSubplot(0.125,0.125;0.775x0.755)
# Male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %% [markdown]
# # Race column!!!

# %%
# Make sure you do df['Race'] = to update the column with the replacements
df['Race'] = df.Race.replace({
    1: 'White',
    2: 'Black',
    4: 'Asian',
    5: 'American Indian',
    6: 'Pacific Islander',
    3: 'Other',
    0: 'Not Stated'
})

# %%
df.head(2)
# Out:
#   CPSC_Case_Number Treatment_Date   Age   Sex   Race Other_Race  Body_Part  \
# 0        170100733     01/01/2017  21.0  Male  White        NaN       75.0
# 1        170100734     01/01/2017  71.0  Male  White        NaN       31.0
#
#    Diagnosis Other_Diagnosis  Disposition  Location  Fire_Involvement  \
# 0       62.0             NaN          1.0       1.0               NaN
# 1       53.0             NaN          1.0       5.0               NaN
#
#    Product_1  Product_2                                        Narrative_1  \
# 0     1207.0        NaN  21YOM WAS BOXING WITH FRIEND WHILE DRINKING AN...
# 1     1807.0        NaN  71YOM FELL ON FLOOR IN BATHROOM. DX RIB CONTUSION
#
#                                          Narrative_2 Stratum   PSU   Weight
# 0  . BAC= 93.6 DX HEAD INJURY AND ALCOHOL INTOXIC...       S  46.0  77.6641
# 1                                                NaN       S  46.0  77.6641

# %% [markdown]
# # Bar chart of the number of times each race shows up in our dataset

# %%
df.Race.value_counts().sort_values().plot(kind='barh')

# %%
df.Race.value_counts(normalize=True)
# Out:
# White               0.666106
# Black               0.225171
# Other               0.083243
# Asian               0.018597
# American Indian     0.005174
# Pacific Islander    0.001709
# Name: Race, dtype: float64

# %%
df.Sex.value_counts(normalize=True)
# Out:
# Male      0.538822
# Female    0.461178
# Name: Sex, dtype: float64

# %%
df.Sex.value_counts()
# Out:
# Male      196165
# Female    167898
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts(dropna=False)
# Out:
# Male      196165
# Female    167898
# NaN            5
# Name: Sex, dtype: int64

# %% [markdown]
# ## Other Race

# %%
df.Other_Race.value_counts().head(10)
# Out:
# HISPANIC        15728
# MULTI-RACIAL     2004
# HISP              760
# SOMALI            361
# NS                300
# UNKN              118
# BIRACIAL           37
# NEPALI             36
# MULTIRACIAL        28
# MULTI RACIAL       24
# Name: Other_Race, dtype: int64

# %%
import numpy as np

df['Other_Race'] = df.Other_Race.replace(["NS", "UNKN"], np.nan)
df.Other_Race.value_counts().head(20)
# Out:
# HISPANIC        15728
# MULTI-RACIAL     2004
# HISP              760
# SOMALI            361
# BIRACIAL           37
# NEPALI             36
# MULTIRACIAL        28
# MULTI RACIAL       24
# NON HISPANIC       14
# PUERTO RICAN       13
# MEXICAN            13
# ARAB               13
# DECLINE            12
# DO NOT KNOW        11
# `                  11
# UNK                10
# HISPAINC            8
# SPANISH             8
# DECLINED            7
# HISAPNIC            6
# Name: Other_Race, dtype: int64

# %%
df[df.Other_Race == "HISPANIC"]
# Out:
#        CPSC_Case_Number Treatment_Date   Age     Sex   Race Other_Race  \
# 117           170106102     01/01/2017   4.0    Male  Other   HISPANIC
# 156           170106239     01/02/2017  10.0  Female  Other   HISPANIC
# 173           170106715     01/01/2017   6.0    Male  Other   HISPANIC
# 174           170106719     01/01/2017  18.0    Male  Other   HISPANIC
# 177           170106722     01/01/2017  10.0    Male  Other   HISPANIC
# 178           170106724     01/01/2017  13.0    Male  Other   HISPANIC
# 180           170106726     01/01/2017   2.0  Female  Other   HISPANIC
# 188           170106886     01/02/2017   4.0    Male  Other   HISPANIC
# 270           170107147     01/02/2017  27.0    Male  Other   HISPANIC
# 316           170107695     01/01/2017  10.0    Male  Other   HISPANIC
# 385           170108633     01/03/2017   2.0    Male  Other   HISPANIC
# 392           170108655     01/03/2017  40.0  Female  Other   HISPANIC
# 529           170109217     01/02/2017  11.0    Male  White   HISPANIC
# 762           170110263     01/03/2017   3.0    Male  Other   HISPANIC
# 1068          170113391     01/01/2017  29.0  Female  Other   HISPANIC
# 1069          170113396     01/01/2017  58.0  Female  Other   HISPANIC
# 1079          170113428     01/01/2017   5.0    Male  Other   HISPANIC
# 1082          170113438     01/02/2017   9.0  Female  Other   HISPANIC
# 1089          170113453     01/02/2017  50.0    Male  Other   HISPANIC
# 1101          170113476     01/02/2017  21.0  Female  Other   HISPANIC
# 1252          170114118     01/06/2017  12.0  Female  White   HISPANIC
# 1282          170114560     01/01/2017  38.0    Male  Other   HISPANIC
# 1344          170115128     01/04/2017   4.0  Female  Other   HISPANIC
# 1375          170115194     01/05/2017   4.0    Male  Other   HISPANIC
# 1669          170116267     01/02/2017  20.0    Male  Other   HISPANIC
# 1670          170116270     01/02/2017  80.0    Male  Other   HISPANIC
# 1785          170116613     01/05/2017   2.0    Male  Other   HISPANIC
# 1794          170116623     01/05/2017  66.0    Male  Other   HISPANIC
# 2034          170117295     01/02/2017  35.0    Male  White   HISPANIC
# 2035          170117296     01/02/2017  20.0    Male  White   HISPANIC
# ...                 ...            ...   ...     ...    ...        ...
# 386393        180233075     12/25/2017  11.0  Female  Other   HISPANIC
# 386394        180233077     12/25/2017   4.0    Male  Other   HISPANIC
# 386396        180233079     12/25/2017   6.0  Female  Other   HISPANIC
# 386398        180233084     12/25/2017  10.0    Male  Other   HISPANIC
# 386530        180236015     12/26/2017   9.0    Male  Other   HISPANIC
# 386531        180236016     12/26/2017   2.0    Male  Other   HISPANIC
# 386532        180236017     12/26/2017  13.0    Male  Other   HISPANIC
# 386534        180236023     12/26/2017   3.0  Female  Other   HISPANIC
# 386535        180236024     12/26/2017   5.0    Male  Other   HISPANIC
# 386537        180236030     12/26/2017  11.0    Male  Other   HISPANIC
# 386538        180236032     12/26/2017   5.0  Female  Other   HISPANIC
# 386539        180236033     12/26/2017   2.0    Male  Other   HISPANIC
# 386540        180236034     12/26/2017   6.0    Male  Other   HISPANIC
# 386541        180236037     12/26/2017   9.0  Female  Other   HISPANIC
# 386543        180236039     12/27/2017   3.0    Male  Other   HISPANIC
# 386544        180236040     12/27/2017   4.0  Female  Other   HISPANIC
# 386545        180236041     12/27/2017   3.0  Female  Other   HISPANIC
# 386546        180236044     12/27/2017   7.0    Male  Other   HISPANIC
# 386549        180236053     12/27/2017  13.0  Female  Other   HISPANIC
# 386553        180236058     12/27/2017  12.0    Male  Other   HISPANIC
# 386555        180236061     12/27/2017   3.0    Male  Other   HISPANIC
# 386556        180236062     12/27/2017  18.0    Male  Other   HISPANIC
# 386557        180236065     12/27/2017   3.0    Male  Other   HISPANIC
# 386562        180236074     12/28/2017   6.0    Male  Other   HISPANIC
# 386568        180236087     12/28/2017   6.0    Male  Other   HISPANIC
# 386572        180236096     12/28/2017   4.0  Female  Other   HISPANIC
# 386663        180240257     12/24/2017  26.0  Female  Other   HISPANIC
# 386665        180240261     12/24/2017  54.0  Female  White   HISPANIC
# 386879        180304321     12/14/2017  17.0  Female  Other   HISPANIC
# 386885        180304327     12/14/2017  32.0  Female  Other   HISPANIC
#
#         Body_Part  Diagnosis       Other_Diagnosis  Disposition  Location  \
# 117          75.0       59.0                   NaN          1.0       NaN
# 156          36.0       59.0                   NaN          1.0       1.0
# 173          75.0       52.0                   NaN          1.0       1.0
# 174          79.0       64.0                   NaN          1.0       1.0
# 177           NaN       41.0                   NaN          1.0       1.0
# 178          35.0       64.0                   NaN          1.0       1.0
# 180          76.0       59.0                   NaN          1.0       1.0
# 188          38.0       71.0           PENILE PAIN          1.0       NaN
# 270          83.0       57.0                   NaN          1.0       1.0
# 316          93.0       53.0                   NaN          1.0       1.0
# 385          76.0       59.0                   NaN          1.0       1.0
# 392          79.0       53.0                   NaN          1.0       1.0
# 529          33.0       57.0                   NaN          1.0       NaN
# 762          75.0       52.0                   NaN          1.0       1.0
# 1068         36.0       59.0                   NaN          1.0       NaN
# 1069         80.0       53.0                   NaN          1.0       NaN
# 1079         92.0       71.0            CELLULITIS          1.0       NaN
# 1082         94.0       56.0                   NaN          1.0       1.0
# 1089         79.0       71.0                  PAIN          1.0       9.0
# 1101         37.0       71.0                INJURY          1.0       NaN
# 1252         31.0       71.0                  PAIN          1.0       NaN
# 1282         77.0       71.0                  PAIN          6.0       NaN
# 1344         76.0       59.0                   NaN          1.0       NaN
# 1375         76.0       59.0                   NaN          1.0       1.0
# 1669         76.0       59.0                   NaN          1.0       1.0
# 1670         31.0       64.0                   NaN          1.0       1.0
# 1785         75.0       62.0                   NaN          1.0       1.0
# 1794         75.0       62.0                   NaN          4.0       1.0
# 2034         82.0       57.0                   NaN          1.0       9.0
# 2035         92.0       56.0                   NaN          1.0       1.0
# ...           ...        ...                   ...          ...       ...
# 386393       81.0       64.0                   NaN          1.0       NaN
# 386394       83.0       71.0                INJURY          1.0       NaN
# 386396       79.0       51.0                   NaN          1.0       1.0
# 386398       77.0       71.0               HYPHEMA          1.0       NaN
# 386530       77.0       71.0  SUBCONJUNCTIVAL HEMO          1.0       NaN
# 386531       35.0       71.0                  PAIN          1.0       NaN
# 386532       92.0       59.0                   NaN          6.0       NaN
# 386534       75.0       59.0                   NaN          6.0       NaN
# 386535       92.0       59.0                   NaN          1.0       NaN
# 386537       38.0       71.0              SWELLING          1.0       NaN
# 386538       83.0       59.0                   NaN          1.0       NaN
# 386539       93.0       72.0                   NaN          1.0       NaN
# 386540       80.0       57.0                   NaN          1.0       NaN
# 386541       34.0       57.0                   NaN          1.0       NaN
# 386543       75.0       52.0                   NaN          1.0       NaN
# 386544       75.0       62.0                   NaN          1.0       NaN
# 386545       75.0       62.0                   NaN          1.0       1.0
# 386546       75.0       62.0                   NaN          4.0       NaN
# 386549       37.0       64.0                   NaN          1.0       NaN
# 386553       75.0       52.0                   NaN          1.0       NaN
# 386555       87.0       74.0                   NaN          1.0       NaN
# 386556       32.0       71.0              EFFUSION          1.0       NaN
# 386557       75.0       62.0                   NaN          1.0       NaN
# 386562       32.0       57.0                   NaN          1.0       NaN
# 386568       80.0       71.0                INJURY          1.0       NaN
# 386572       92.0       56.0                   NaN          1.0       NaN
# 386663       37.0       64.0                   NaN          1.0       NaN
# 386665       34.0       57.0                   NaN          1.0       1.0
# 386879       35.0       64.0                   NaN          1.0       9.0
# 386885       83.0       64.0                   NaN          1.0       NaN
#
#         Fire_Involvement  Product_1  Product_2  \
# 117                  NaN      379.0        NaN
# 156                  NaN     1842.0        NaN
# 173                  NaN     1807.0        NaN
# 174                  NaN      604.0        NaN
# 177                  NaN     1682.0        NaN
# 178                  NaN     1233.0        NaN
# 180                  NaN     4057.0        NaN
# 188                  NaN      649.0        NaN
# 270                  NaN     1842.0        NaN
# 316                  NaN     5019.0        NaN
# 385                  NaN     4057.0        NaN
# 392                  NaN     1842.0        NaN
# 529                  NaN     1842.0        NaN
# 762                  NaN     1545.0        NaN
# 1068                 NaN     1140.0        NaN
# 1069                 NaN     1602.0        NaN
# 1079                 NaN     1893.0        NaN
# 1082                 NaN     1685.0        NaN
# 1089                 NaN     3255.0     1206.0
# 1101                 NaN     1842.0        NaN
# 1252                 NaN      566.0        NaN
# 1282                 NaN     1720.0        NaN
# 1344                 NaN     3277.0        NaN
# 1375                 NaN     4076.0        NaN
# 1669                 NaN      478.0        NaN
# 1670                 NaN     4074.0        NaN
# 1785                 NaN      679.0     1807.0
# 1794                 NaN     4076.0      676.0
# 2034                 NaN     3286.0        NaN
# 2035                 NaN      834.0     1885.0
# ...                  ...        ...        ...
# 386393               NaN      679.0        NaN
# 386394               NaN     3273.0        NaN
# 386396               NaN      393.0        NaN
# 386398               NaN     1399.0        NaN
# 386530               NaN     1389.0        NaN
# 386531               NaN     1807.0        NaN
# 386532               NaN      474.0        NaN
# 386534               NaN     4057.0        NaN
# 386535               NaN     5042.0        NaN
# 386537               NaN     1233.0        NaN
# 386538               NaN     1616.0        NaN
# 386539               NaN     4057.0        NaN
# 386540               NaN     1842.0        NaN
# 386541               NaN     3246.0        NaN
# 386543               NaN     5021.0        NaN
# 386544               NaN      611.0     1807.0
# 386545               NaN      519.0        NaN
# 386546               NaN     3287.0     1213.0
# 386549               NaN     1842.0        NaN
# 386553               NaN     3287.0     3259.0
# 386555               NaN     1644.0        NaN
# 386556               NaN      557.0     1842.0
# 386557               NaN     1807.0        NaN
# 386562               NaN     4076.0        NaN
# 386568               NaN      679.0     1807.0
# 386572               NaN     5021.0        NaN
# 386663               NaN     1615.0        NaN
# 386665               NaN      612.0        NaN
# 386879               NaN     1272.0        NaN
# 386885               NaN     1842.0        NaN
#
#                                               Narrative_1  \
# 117     4 YOM FELL AND HIT RADIATOR.  DX SCALP LACERATION
# 156             10YOF WITH LAC TO LOWER LEG FROM ON STEPS
# 173     6YOM- PT WAS RUNNING IN THE HOME FELL STUCK HE...
# 174     18YOM-PT WAS HOME MOVING A DRESSER SOMETHING P...
# 177     10YOM-PT HAD A BOBBY PIN IN MOUTH & ACCIDENTAL...
# 178     13YOM-PT WAS JUMPING ON A TRAMPLOLINE W/ FRIEN...
# 180     2YOF-PT FELL HITTING FOREHEAD ONTO THE TABLE P...
# 188     4YOM DROPPED A TOILET SEAT ON HIS PENIS 2 MONT...
# 270     LEFT FDOT FX. 27 YOM WAS RUNNING DOWNSTAIRS WH...
# 316     10 YOM C/O LEFT MIDDLE TOE PAIN AFTER DROPPING...
# 385             2YOM WITH LAC TO FACE, FELL AGAINST TABLE
# 392          40YOF WITH CONTUSION TO HIP, FELL DOWN STEPS
# 529     11YOM WAS WALKING UP THE STAIRS WHEN HE FELL O...
# 762                  3 YOM FELL FROM CRIB.  DX CONCUSSION
# 1068    *29YOF,HOLDING GLASS BOTTLE DROPPED BROKE,CUT ...
# 1069    *58YOF,UPPER ARM 3DAY AGO HIT W/HAIR DRYER ON ...
# 1079    *5YOM,1WK AGO SISTER SLAMMED DOOR ON FINGER,KN...
# 1082    *9YOF,PUT A PLASTIC PEN INTO EAR WENT IN,DX:FB...
# 1089    *50YOM,ICE SKATING FELL FWD THEN BOWLING DEVEL...
# 1101    *21YOF,GOING DOWN STAIRS MISSED STEP ANKLE PAI...
# 1252    12YOF HAS LEFT CHEST PAIN THAT DEVELOPED WHILE...
# 1282    38 YO M C/O RIGHT EYE PAIN S/P A POPPER HIT HI...
# 1344    4 YOF PLAYING ON AN EXERCISE BIKE AND FELL, HI...
# 1375      4YOM JUMPING ON THE BED, FELL AND HIT FOREHEAD.
# 1669    20YOM LAC TO FOREHEAD WHEN LOST BALANCE WHILE ...
# 1670    80YOM PAIN TO RIBS WHEN FELL TRYING TO SIT IN ...
# 1785    2 YOM INJURED HEAD,FALL OFF COUCH ONTO FLOOR A...
# 1794    66 YOM INJURED HEAD,FELL OFF EDGE OF BED ONTO ...
# 2034    35YOM REPORTS LOST CONTROL OF ATV IT FLIPPED O...
# 2035    20YOM REPORTS FELL OVER BOARD AND STAPLE FROM ...
# ...                                                   ...
# 386393  11YOF SWUNG LEGS AROUND ON COUCH TO QUCKLY STA...
# 386394  4YOM JUMPED DOWN FROM PLAYGROUND EQUIPMENT AND...
# 386396  6YOF BACK UP INTO SPACE HEATER IN BATHROOM AT ...
# 386398  10YOM PLAYING WITH *** GUN AND SHOT A FOAM BAL...
# 386530  9YOM PLAYING WITH WOODEN SWORD TOY WITH BROTHE...
# 386531  2YOM RUNNING AND TRIPPED AND HIT RIGHT KNEE ON...
# 386532  13YOM BROKE COFFEE MUG, CUT RIGHT FINGER. POSS...
# 386534  3YOF RAN INTO TABLE CORNER LAC TO RIGHT FRONTA...
# 386535  5YOM PLAYING WITH ELECTRIC SCOOTER AND PUT HIS...
# 386537  11YOM LANDED ON BAR OF TRAMPOLINE DX SCROTAL S...
# 386538  5YOF CUT BOTTOM OF FOOT ON BROKEN GLASS EARRIN...
# 386539  2YOM METAL TABLE FELL ON TOE RIGHT TOENAIL AVU...
# 386540  6YOM PLAYING ON SMALL STAIRCASE (5 STEPS) AND ...
# 386541  9YOF FELL OFF SWING ONTO GRASS, HIT NOSE BUT N...
# 386543  3YOM PLAYING WITH TRAINSET, UNWITNESSED FALL O...
# 386544  4YOF FELL WHILE EXITING BATH AND HIT MOUTH ON ...
# 386545  3YOF SLIPPED WHILE PLAYING AT HOME AND HIT HEA...
# 386546  7YOM UNHELMETED ON ATV (2-PERSON) AND REAR-END...
# 386549  13YOF ROLLED RIGHT ANKLE WHILE WALKING DOWN ST...
# 386553  12YOM DRIVING ATV, CUT OFF BY GO-CART W/O BREA...
# 386555  3YOM WITH MIGRATING RASH AFTER WEARING NEW PAJ...
# 386556  18YOM FELL WHILE TRYING TO INSTALL VIDEO GAME ...
# 386557  3YOM STRUCK HEAD ON BATHROOM FLOOR DURING FEBR...
# 386562  6YOM PLAYING WITH SIBLINGS AND FELL OFF BED, L...
# 386568  6YOM JUMPED FROM SOFA LANDED ON HARD FLOOR NO ...
# 386572  4YOF PLAYING WITH REMOTE CONTROL TOY CAR AND G...
# 386663  26YOF S/P TRIP/FALL WEARING SANDALS 34WKS PREG...
# 386665              54YOF C/O WRIST PAIN S/P FALL  ON MAT
# 386879  17YOHF INJ KNEE DURING GYMNASTIC RPTS DOING JU...
# 386885  32YOHF MISSING A STEP W GOIND DOWN STAIRS ROLL...
#
#                                               Narrative_2 Stratum   PSU  \
# 117                                                   NaN       C  31.0
# 156                                                   NaN       V  61.0
# 173           VOMITED X 2. ACTING SLEEPY. DX- CONCUSSION.       C  90.0
# 174     ABDOMINAL AREA. DX- STRAIN OF LEFT SIDED ABDOMIN.       C  90.0
# 177                              DX- SWALLOWED BOBBY PIN.       C  90.0
# 178              KNEE. FELT A POP. DX- RIGHT KNEE SPRAIN.       C  90.0
# 180              FOREHEAD. DX- 0.5CM FOREHEAD LACERATION.       C  90.0
# 188     DISCHARGE AND PAIN FOR 3 DAYS; PENILE PAIN AND...       C   8.0
# 270                            STEP AND TWISTED HIS FOOT.       V  95.0
# 316                                     DX: TOE CONTUSION       V  61.0
# 385                                                   NaN       V  61.0
# 392                                                   NaN       V  61.0
# 529                          RIGHT HAND; FOREARM FRACTURE       C   8.0
# 762                                                   NaN       C  31.0
# 1068                                                  NaN       M  24.0
# 1069                                                   RM       M  24.0
# 1079                                     R,DX:CELL FINGER       M  24.0
# 1082                                                  NaN       M  24.0
# 1089                                                   IN       M  24.0
# 1101                                                  NaN       M  24.0
# 1252                                      CHEST WALL PAIN       S  46.0
# 1282                                                  NaN       L  51.0
# 1344                                         E LACERATION       C  31.0
# 1375                                      DX.   LAC. FACE       S  29.0
# 1669                                                  LAC       L  42.0
# 1670                               F CHAIR. / SPRAIN RIBS       L  42.0
# 1785                                                  NaN       M  78.0
# 1794        DX-SYNCOPE,HEAD INJURY,HYPERGLYCEMIA,ADMITTED       M  78.0
# 2034                        DX:OPEN FRACTURE LEFT HAND. *       V  91.0
# 2035            LEFT PINKY FINGER.DX:FB LEFT 5TH FINGER.*       V  91.0
# ...                                                   ...     ...   ...
# 386393      RIGHT LEG AND HIP DX RIGHT QUADRICEPS STRAIN/       C  10.0
# 386394      LLING +PAIN NO FRACTURE DX RIGHT FOOT INJURY/       C  10.0
# 386396                          DX BURN OF RIGHT BUTTOCK/       C  10.0
# 386398  CAR THAT BOUNCED OFF CAR WINDOW AND HIT RIGHT ...       C  10.0
# 386530  NOW WITH EYE INJURY DX SUBCONJUNCTIVAL HEMORRH...       C  10.0
# 386531              Y NO LOC DX ACUTE PAIN OF RIGHT KNEE/       C  10.0
# 386532                                       LACERATION /       C  10.0
# 386534                         G SEEN DX HEAD LACERATION/       C  10.0
# 386535                            IGHT FINGER LACERATION/       C  10.0
# 386537                                                NaN       C  10.0
# 386538                                  INVOLVING TENDON/       C  10.0
# 386539                                                NaN       C  10.0
# 386540  ND OR DIRECTLY ON LEFT ELBOW NO LOC DX LEFT SU...       C  10.0
# 386541                        ISTAL RADIUS ULNA FRACTURE/       C  10.0
# 386543  AND ATAXIA, DECREASED ACTIVITY AND APPETITE DX...       C  10.0
# 386544                                                RY/       C  10.0
# 386545                   OREHEAD LACERATION, HEAD INJURY/       C  10.0
# 386546  FF. GCS 13-15. DX SUBARACHNOID HEMORRHAGE, PAR...       C  10.0
# 386549                                                 N/       C  10.0
# 386553  RT AND ROLLED. NO HELMET. +LOC. DX CLOSED HEAD...       C  10.0
# 386555                                                NaN       C  10.0
# 386556  WN 4 STAIRS LANDED ON LEFT ELBOW NO FX DX LEFT...       C  10.0
# 386557                                Y, FEBRILE SEIZURE/       C  10.0
# 386562        LOC NO HEAD INJURY DX RIGHT ELBOW FRACTURE/       C  10.0
# 386568                                                RY/       C  10.0
# 386572                       R DX FOREIGN BODY OF FINGER/       C  10.0
# 386663                                 DX: L ANKLE SPRAIN       V  40.0
# 386665                              DX:L DISTAL RADIUS FX       V  40.0
# 386879  A POP: DX KNEE SPRAIN/SPAIN LAT COLL LIG KNEE/...       V  67.0
# 386885                                                NaN       V  67.0
#
#          Weight
# 117      4.7570
# 156     16.1828
# 173      4.7570
# 174      4.7570
# 177      4.7570
# 178      4.7570
# 180      4.7570
# 188      4.7570
# 270     16.1828
# 316     16.1828
# 385     16.1828
# 392     16.1828
# 529      4.7570
# 762      4.7570
# 1068    87.0904
# 1069    87.0904
# 1079    87.0904
# 1082    87.0904
# 1089    87.0904
# 1101    87.0904
# 1252    77.6641
# 1282    67.2099
# 1344     4.7570
# 1375    77.6641
# 1669    67.2099
# 1670    67.2099
# 1785    87.0904
# 1794    87.0904
# 2034    16.1828
# 2035    16.1828
# ...         ...
# 386393   4.7570
# 386394   4.7570
# 386396   4.7570
# 386398   4.7570
# 386530   4.7570
# 386531   4.7570
# 386532   4.7570
# 386534   4.7570
# 386535   4.7570
# 386537   4.7570
# 386538   4.7570
# 386539   4.7570
# 386540   4.7570
# 386541   4.7570
# 386543   4.7570
# 386544   4.7570
# 386545   4.7570
# 386546   4.7570
# 386549   4.7570
# 386553   4.7570
# 386555   4.7570
# 386556   4.7570
# 386557   4.7570
# 386562   4.7570
# 386568   4.7570
# 386572   4.7570
# 386663  16.9919
# 386665  16.9919
# 386879  16.9919
# 386885  16.9919
#
# [15728 rows x 19 columns]

# %%
df[df.Other_Race.str.contains("HISP", na=False)]
# Out:
#        CPSC_Case_Number Treatment_Date   Age     Sex   Race Other_Race  \
# 117           170106102     01/01/2017   4.0    Male  Other   HISPANIC
# 156           170106239     01/02/2017  10.0  Female  Other   HISPANIC
# 173           170106715     01/01/2017   6.0    Male  Other   HISPANIC
# 174           170106719     01/01/2017  18.0    Male  Other   HISPANIC
# 177           170106722     01/01/2017  10.0    Male  Other   HISPANIC
# 178           170106724     01/01/2017  13.0    Male  Other   HISPANIC
# 180           170106726     01/01/2017   2.0  Female  Other   HISPANIC
# 188           170106886     01/02/2017   4.0    Male  Other   HISPANIC
# 270           170107147     01/02/2017  27.0    Male  Other   HISPANIC
# 316           170107695     01/01/2017  10.0    Male  Other   HISPANIC
# 385           170108633     01/03/2017   2.0    Male  Other   HISPANIC
# 392           170108655     01/03/2017  40.0  Female  Other   HISPANIC
# 529           170109217     01/02/2017  11.0    Male  White   HISPANIC
# 762           170110263     01/03/2017   3.0    Male  Other   HISPANIC
# 1068          170113391     01/01/2017  29.0  Female  Other   HISPANIC
# 1069          170113396     01/01/2017  58.0  Female  Other   HISPANIC
# 1079          170113428     01/01/2017   5.0    Male  Other   HISPANIC
# 1082          170113438     01/02/2017   9.0  Female  Other   HISPANIC
# 1089          170113453     01/02/2017  50.0    Male  Other   HISPANIC
# 1101          170113476     01/02/2017  21.0  Female  Other   HISPANIC
# 1252          170114118     01/06/2017  12.0  Female  White   HISPANIC
# 1282          170114560     01/01/2017  38.0    Male  Other   HISPANIC
# 1344          170115128     01/04/2017   4.0  Female  Other   HISPANIC
# 1375          170115194     01/05/2017   4.0    Male  Other   HISPANIC
# 1669          170116267     01/02/2017  20.0    Male  Other   HISPANIC
# 1670          170116270     01/02/2017  80.0    Male  Other   HISPANIC
# 1785          170116613     01/05/2017   2.0    Male  Other   HISPANIC
# 1794          170116623     01/05/2017  66.0    Male  Other   HISPANIC
# 2034          170117295     01/02/2017  35.0    Male  White   HISPANIC
# 2035          170117296     01/02/2017  20.0    Male  White   HISPANIC
# ...                 ...            ...   ...     ...    ...        ...
# 386393        180233075     12/25/2017  11.0  Female  Other   HISPANIC
# 386394        180233077     12/25/2017   4.0    Male  Other   HISPANIC
# 386396        180233079     12/25/2017   6.0  Female  Other   HISPANIC
# 386398        180233084     12/25/2017  10.0    Male  Other   HISPANIC
# 386530        180236015     12/26/2017   9.0    Male  Other   HISPANIC
# 386531        180236016     12/26/2017   2.0    Male  Other   HISPANIC
# 386532        180236017     12/26/2017  13.0    Male  Other   HISPANIC
# 386534        180236023     12/26/2017   3.0  Female  Other   HISPANIC
# 386535        180236024     12/26/2017   5.0    Male  Other   HISPANIC
# 386537        180236030     12/26/2017  11.0    Male  Other   HISPANIC
# 386538        180236032     12/26/2017   5.0  Female  Other   HISPANIC
# 386539        180236033     12/26/2017   2.0    Male  Other   HISPANIC
# 386540        180236034     12/26/2017   6.0    Male  Other   HISPANIC
# 386541        180236037     12/26/2017   9.0  Female  Other   HISPANIC
# 386543        180236039     12/27/2017   3.0    Male  Other   HISPANIC
# 386544        180236040     12/27/2017   4.0  Female  Other   HISPANIC
# 386545        180236041     12/27/2017   3.0  Female  Other   HISPANIC
# 386546        180236044     12/27/2017   7.0    Male  Other   HISPANIC
# 386549        180236053     12/27/2017  13.0  Female  Other   HISPANIC
# 386553        180236058     12/27/2017  12.0    Male  Other   HISPANIC
# 386555        180236061     12/27/2017   3.0    Male  Other   HISPANIC
# 386556        180236062     12/27/2017  18.0    Male  Other   HISPANIC
# 386557        180236065     12/27/2017   3.0    Male  Other   HISPANIC
# 386562        180236074     12/28/2017   6.0    Male  Other   HISPANIC
# 386568        180236087     12/28/2017   6.0    Male  Other   HISPANIC
# 386572        180236096     12/28/2017   4.0  Female  Other   HISPANIC
# 386663        180240257     12/24/2017  26.0  Female  Other   HISPANIC
# 386665        180240261     12/24/2017  54.0  Female  White   HISPANIC
# 386879        180304321     12/14/2017  17.0  Female  Other   HISPANIC
# 386885        180304327     12/14/2017  32.0  Female  Other   HISPANIC
#
#         Body_Part  Diagnosis       Other_Diagnosis  Disposition  Location  \
# 117          75.0       59.0                   NaN          1.0       NaN
# 156          36.0       59.0                   NaN          1.0       1.0
# 173          75.0       52.0                   NaN          1.0       1.0
# 174          79.0       64.0                   NaN          1.0       1.0
# 177           NaN       41.0                   NaN          1.0       1.0
# 178          35.0       64.0                   NaN          1.0       1.0
# 180          76.0       59.0                   NaN          1.0       1.0
# 188          38.0       71.0           PENILE PAIN          1.0       NaN
# 270          83.0       57.0                   NaN          1.0       1.0
# 316          93.0       53.0                   NaN          1.0       1.0
# 385          76.0       59.0                   NaN          1.0       1.0
# 392          79.0       53.0                   NaN          1.0       1.0
# 529          33.0       57.0                   NaN          1.0       NaN
# 762          75.0       52.0                   NaN          1.0       1.0
# 1068         36.0       59.0                   NaN          1.0       NaN
# 1069         80.0       53.0                   NaN          1.0       NaN
# 1079         92.0       71.0            CELLULITIS          1.0       NaN
# 1082         94.0       56.0                   NaN          1.0       1.0
# 1089         79.0       71.0                  PAIN          1.0       9.0
# 1101         37.0       71.0                INJURY          1.0       NaN
# 1252         31.0       71.0                  PAIN          1.0       NaN
# 1282         77.0       71.0                  PAIN          6.0       NaN
# 1344         76.0       59.0                   NaN          1.0       NaN
# 1375         76.0       59.0                   NaN          1.0       1.0
# 1669         76.0       59.0                   NaN          1.0       1.0
# 1670         31.0       64.0                   NaN          1.0       1.0
# 1785         75.0       62.0                   NaN          1.0       1.0
# 1794         75.0       62.0                   NaN          4.0       1.0
# 2034         82.0       57.0                   NaN          1.0       9.0
# 2035         92.0       56.0                   NaN          1.0       1.0
# ...           ...        ...                   ...          ...       ...
# 386393       81.0       64.0                   NaN          1.0       NaN
# 386394       83.0       71.0                INJURY          1.0       NaN
# 386396       79.0       51.0                   NaN          1.0       1.0
# 386398       77.0       71.0               HYPHEMA          1.0       NaN
# 386530       77.0       71.0  SUBCONJUNCTIVAL HEMO          1.0       NaN
# 386531       35.0       71.0                  PAIN          1.0       NaN
# 386532       92.0       59.0                   NaN          6.0       NaN
# 386534       75.0       59.0                   NaN          6.0       NaN
# 386535       92.0       59.0                   NaN          1.0       NaN
# 386537       38.0       71.0              SWELLING          1.0       NaN
# 386538       83.0       59.0                   NaN          1.0       NaN
# 386539       93.0       72.0                   NaN          1.0       NaN
# 386540       80.0       57.0                   NaN          1.0       NaN
# 386541       34.0       57.0                   NaN          1.0       NaN
# 386543       75.0       52.0                   NaN          1.0       NaN
# 386544       75.0       62.0                   NaN          1.0       NaN
# 386545       75.0       62.0                   NaN          1.0       1.0
# 386546       75.0       62.0                   NaN          4.0       NaN
# 386549       37.0       64.0                   NaN          1.0       NaN
# 386553       75.0       52.0                   NaN          1.0       NaN
# 386555       87.0       74.0                   NaN          1.0       NaN
# 386556       32.0       71.0              EFFUSION          1.0       NaN
# 386557       75.0       62.0                   NaN          1.0       NaN
# 386562       32.0       57.0                   NaN          1.0       NaN
# 386568       80.0       71.0                INJURY          1.0       NaN
# 386572       92.0       56.0                   NaN          1.0       NaN
# 386663       37.0       64.0                   NaN          1.0       NaN
# 386665       34.0       57.0                   NaN          1.0       1.0
# 386879       35.0       64.0                   NaN          1.0       9.0
# 386885       83.0       64.0                   NaN          1.0       NaN
#
#         Fire_Involvement  Product_1  Product_2  \
# 117                  NaN      379.0        NaN
# 156                  NaN     1842.0        NaN
# 173                  NaN     1807.0        NaN
# 174                  NaN      604.0        NaN
# 177                  NaN     1682.0        NaN
# 178                  NaN     1233.0        NaN
# 180                  NaN     4057.0        NaN
# 188                  NaN      649.0        NaN
# 270                  NaN     1842.0        NaN
# 316                  NaN     5019.0        NaN
# 385                  NaN     4057.0        NaN
# 392                  NaN     1842.0        NaN
# 529                  NaN     1842.0        NaN
# 762                  NaN     1545.0        NaN
# 1068                 NaN     1140.0        NaN
# 1069                 NaN     1602.0        NaN
# 1079                 NaN     1893.0        NaN
# 1082                 NaN     1685.0        NaN
# 1089                 NaN     3255.0     1206.0
# 1101                 NaN     1842.0        NaN
# 1252                 NaN      566.0        NaN
# 1282                 NaN     1720.0        NaN
# 1344                 NaN     3277.0        NaN
# 1375                 NaN     4076.0        NaN
# 1669                 NaN      478.0        NaN
# 1670                 NaN     4074.0        NaN
# 1785                 NaN      679.0     1807.0
# 1794                 NaN     4076.0      676.0
# 2034                 NaN     3286.0        NaN
# 2035                 NaN      834.0     1885.0
# ...                  ...        ...        ...
# 386393               NaN      679.0        NaN
# 386394               NaN     3273.0        NaN
# 386396               NaN      393.0        NaN
# 386398               NaN     1399.0        NaN
# 386530               NaN     1389.0        NaN
# 386531               NaN     1807.0        NaN
# 386532               NaN      474.0        NaN
# 386534               NaN     4057.0        NaN
# 386535               NaN     5042.0        NaN
# 386537               NaN     1233.0        NaN
# 386538               NaN     1616.0        NaN
# 386539               NaN     4057.0        NaN
# 386540               NaN     1842.0        NaN
# 386541               NaN     3246.0        NaN
# 386543               NaN     5021.0        NaN
# 386544               NaN      611.0     1807.0
# 386545               NaN      519.0        NaN
# 386546               NaN     3287.0     1213.0
# 386549               NaN     1842.0        NaN
# 386553               NaN     3287.0     3259.0
# 386555               NaN     1644.0        NaN
# 386556               NaN      557.0     1842.0
# 386557               NaN     1807.0        NaN
# 386562               NaN     4076.0        NaN
# 386568               NaN      679.0     1807.0
# 386572               NaN     5021.0        NaN
# 386663               NaN     1615.0        NaN
# 386665               NaN      612.0        NaN
# 386879               NaN     1272.0        NaN
# 386885               NaN     1842.0        NaN
#
#                                               Narrative_1  \
# 117     4 YOM FELL AND HIT RADIATOR.  DX SCALP LACERATION
# 156             10YOF WITH LAC TO LOWER LEG FROM ON STEPS
# 173     6YOM- PT WAS RUNNING IN THE HOME FELL STUCK HE...
# 174     18YOM-PT WAS HOME MOVING A DRESSER SOMETHING P...
# 177     10YOM-PT HAD A BOBBY PIN IN MOUTH & ACCIDENTAL...
# 178     13YOM-PT WAS JUMPING ON A TRAMPLOLINE W/ FRIEN...
# 180     2YOF-PT FELL HITTING FOREHEAD ONTO THE TABLE P...
# 188     4YOM DROPPED A TOILET SEAT ON HIS PENIS 2 MONT...
# 270     LEFT FDOT FX. 27 YOM WAS RUNNING DOWNSTAIRS WH...
# 316     10 YOM C/O LEFT MIDDLE TOE PAIN AFTER DROPPING...
# 385             2YOM WITH LAC TO FACE, FELL AGAINST TABLE
# 392          40YOF WITH CONTUSION TO HIP, FELL DOWN STEPS
# 529     11YOM WAS WALKING UP THE STAIRS WHEN HE FELL O...
# 762                  3 YOM FELL FROM CRIB.  DX CONCUSSION
# 1068    *29YOF,HOLDING GLASS BOTTLE DROPPED BROKE,CUT ...
# 1069    *58YOF,UPPER ARM 3DAY AGO HIT W/HAIR DRYER ON ...
# 1079    *5YOM,1WK AGO SISTER SLAMMED DOOR ON FINGER,KN...
# 1082    *9YOF,PUT A PLASTIC PEN INTO EAR WENT IN,DX:FB...
# 1089    *50YOM,ICE SKATING FELL FWD THEN BOWLING DEVEL...
# 1101    *21YOF,GOING DOWN STAIRS MISSED STEP ANKLE PAI...
# 1252    12YOF HAS LEFT CHEST PAIN THAT DEVELOPED WHILE...
# 1282    38 YO M C/O RIGHT EYE PAIN S/P A POPPER HIT HI...
# 1344    4 YOF PLAYING ON AN EXERCISE BIKE AND FELL, HI...
# 1375      4YOM JUMPING ON THE BED, FELL AND HIT FOREHEAD.
# 1669    20YOM LAC TO FOREHEAD WHEN LOST BALANCE WHILE ...
# 1670    80YOM PAIN TO RIBS WHEN FELL TRYING TO SIT IN ...
# 1785    2 YOM INJURED HEAD,FALL OFF COUCH ONTO FLOOR A...
# 1794    66 YOM INJURED HEAD,FELL OFF EDGE OF BED ONTO ...
# 2034    35YOM REPORTS LOST CONTROL OF ATV IT FLIPPED O...
# 2035    20YOM REPORTS FELL OVER BOARD AND STAPLE FROM ...
# ...                                                   ...
# 386393  11YOF SWUNG LEGS AROUND ON COUCH TO QUCKLY STA...
# 386394  4YOM JUMPED DOWN FROM PLAYGROUND EQUIPMENT AND...
# 386396  6YOF BACK UP INTO SPACE HEATER IN BATHROOM AT ...
# 386398  10YOM PLAYING WITH *** GUN AND SHOT A FOAM BAL...
# 386530  9YOM PLAYING WITH WOODEN SWORD TOY WITH BROTHE...
# 386531  2YOM RUNNING AND TRIPPED AND HIT RIGHT KNEE ON...
# 386532  13YOM BROKE COFFEE MUG, CUT RIGHT FINGER. POSS...
# 386534  3YOF RAN INTO TABLE CORNER LAC TO RIGHT FRONTA...
# 386535  5YOM PLAYING WITH ELECTRIC SCOOTER AND PUT HIS...
# 386537  11YOM LANDED ON BAR OF TRAMPOLINE DX SCROTAL S...
# 386538  5YOF CUT BOTTOM OF FOOT ON BROKEN GLASS EARRIN...
# 386539  2YOM METAL TABLE FELL ON TOE RIGHT TOENAIL AVU...
# 386540  6YOM PLAYING ON SMALL STAIRCASE (5 STEPS) AND ...
# 386541  9YOF FELL OFF SWING ONTO GRASS, HIT NOSE BUT N...
# 386543  3YOM PLAYING WITH TRAINSET, UNWITNESSED FALL O...
# 386544  4YOF FELL WHILE EXITING BATH AND HIT MOUTH ON ...
# 386545  3YOF SLIPPED WHILE PLAYING AT HOME AND HIT HEA...
# 386546  7YOM UNHELMETED ON ATV (2-PERSON) AND REAR-END...
# 386549  13YOF ROLLED RIGHT ANKLE WHILE WALKING DOWN ST...
# 386553  12YOM DRIVING ATV, CUT OFF BY GO-CART W/O BREA...
# 386555  3YOM WITH MIGRATING RASH AFTER WEARING NEW PAJ...
# 386556  18YOM FELL WHILE TRYING TO INSTALL VIDEO GAME ...
# 386557  3YOM STRUCK HEAD ON BATHROOM FLOOR DURING FEBR...
# 386562  6YOM PLAYING WITH SIBLINGS AND FELL OFF BED, L...
# 386568  6YOM JUMPED FROM SOFA LANDED ON HARD FLOOR NO ...
# 386572  4YOF PLAYING WITH REMOTE CONTROL TOY CAR AND G...
# 386663  26YOF S/P TRIP/FALL WEARING SANDALS 34WKS PREG...
# 386665              54YOF C/O WRIST PAIN S/P FALL  ON MAT
# 386879  17YOHF INJ KNEE DURING GYMNASTIC RPTS DOING JU...
# 386885  32YOHF MISSING A STEP W GOIND DOWN STAIRS ROLL...
#
#                                               Narrative_2 Stratum   PSU  \
# 117                                                   NaN       C  31.0
# 156                                                   NaN       V  61.0
# 173           VOMITED X 2. ACTING SLEEPY. DX- CONCUSSION.       C  90.0
# 174     ABDOMINAL AREA. DX- STRAIN OF LEFT SIDED ABDOMIN.       C  90.0
# 177                              DX- SWALLOWED BOBBY PIN.       C  90.0
# 178              KNEE. FELT A POP. DX- RIGHT KNEE SPRAIN.       C  90.0
# 180              FOREHEAD. DX- 0.5CM FOREHEAD LACERATION.       C  90.0
# 188     DISCHARGE AND PAIN FOR 3 DAYS; PENILE PAIN AND...       C   8.0
# 270                            STEP AND TWISTED HIS FOOT.       V  95.0
# 316                                     DX: TOE CONTUSION       V  61.0
# 385                                                   NaN       V  61.0
# 392                                                   NaN       V  61.0
# 529                          RIGHT HAND; FOREARM FRACTURE       C   8.0
# 762                                                   NaN       C  31.0
# 1068                                                  NaN       M  24.0
# 1069                                                   RM       M  24.0
# 1079                                     R,DX:CELL FINGER       M  24.0
# 1082                                                  NaN       M  24.0
# 1089                                                   IN       M  24.0
# 1101                                                  NaN       M  24.0
# 1252                                      CHEST WALL PAIN       S  46.0
# 1282                                                  NaN       L  51.0
# 1344                                         E LACERATION       C  31.0
# 1375                                      DX.   LAC. FACE       S  29.0
# 1669                                                  LAC       L  42.0
# 1670                               F CHAIR. / SPRAIN RIBS       L  42.0
# 1785                                                  NaN       M  78.0
# 1794        DX-SYNCOPE,HEAD INJURY,HYPERGLYCEMIA,ADMITTED       M  78.0
# 2034                        DX:OPEN FRACTURE LEFT HAND. *       V  91.0
# 2035            LEFT PINKY FINGER.DX:FB LEFT 5TH FINGER.*       V  91.0
# ...                                                   ...     ...   ...
# 386393      RIGHT LEG AND HIP DX RIGHT QUADRICEPS STRAIN/       C  10.0
# 386394      LLING +PAIN NO FRACTURE DX RIGHT FOOT INJURY/       C  10.0
# 386396                          DX BURN OF RIGHT BUTTOCK/       C  10.0
# 386398  CAR THAT BOUNCED OFF CAR WINDOW AND HIT RIGHT ...       C  10.0
# 386530  NOW WITH EYE INJURY DX SUBCONJUNCTIVAL HEMORRH...       C  10.0
# 386531              Y NO LOC DX ACUTE PAIN OF RIGHT KNEE/       C  10.0
# 386532                                       LACERATION /       C  10.0
# 386534                         G SEEN DX HEAD LACERATION/       C  10.0
# 386535                            IGHT FINGER LACERATION/       C  10.0
# 386537                                                NaN       C  10.0
# 386538                                  INVOLVING TENDON/       C  10.0
# 386539                                                NaN       C  10.0
# 386540  ND OR DIRECTLY ON LEFT ELBOW NO LOC DX LEFT SU...       C  10.0
# 386541                        ISTAL RADIUS ULNA FRACTURE/       C  10.0
# 386543  AND ATAXIA, DECREASED ACTIVITY AND APPETITE DX...       C  10.0
# 386544                                                RY/       C  10.0
# 386545                   OREHEAD LACERATION, HEAD INJURY/       C  10.0
# 386546  FF. GCS 13-15. DX SUBARACHNOID HEMORRHAGE, PAR...       C  10.0
# 386549                                                 N/       C  10.0
# 386553  RT AND ROLLED. NO HELMET. +LOC. DX CLOSED HEAD...       C  10.0
# 386555                                                NaN       C  10.0
# 386556  WN 4 STAIRS LANDED ON LEFT ELBOW NO FX DX LEFT...       C  10.0
# 386557                                Y, FEBRILE SEIZURE/       C  10.0
# 386562        LOC NO HEAD INJURY DX RIGHT ELBOW FRACTURE/       C  10.0
# 386568                                                RY/       C  10.0
# 386572                       R DX FOREIGN BODY OF FINGER/       C  10.0
# 386663                                 DX: L ANKLE SPRAIN       V  40.0
# 386665                              DX:L DISTAL RADIUS FX       V  40.0
# 386879  A POP: DX KNEE SPRAIN/SPAIN LAT COLL LIG KNEE/...       V  67.0
# 386885                                                NaN       V  67.0
#
#          Weight
# 117      4.7570
# 156     16.1828
# 173      4.7570
# 174      4.7570
# 177      4.7570
# 178      4.7570
# 180      4.7570
# 188      4.7570
# 270     16.1828
# 316     16.1828
# 385     16.1828
# 392     16.1828
# 529      4.7570
# 762      4.7570
# 1068    87.0904
# 1069    87.0904
# 1079    87.0904
# 1082    87.0904
# 1089    87.0904
# 1101    87.0904
# 1252    77.6641
# 1282    67.2099
# 1344     4.7570
# 1375    77.6641
# 1669    67.2099
# 1670    67.2099
# 1785    87.0904
# 1794    87.0904
# 2034    16.1828
# 2035    16.1828
# ...         ...
# 386393   4.7570
# 386394   4.7570
# 386396   4.7570
# 386398   4.7570
# 386530   4.7570
# 386531   4.7570
# 386532   4.7570
# 386534   4.7570
# 386535   4.7570
# 386537   4.7570
# 386538   4.7570
# 386539   4.7570
# 386540   4.7570
# 386541   4.7570
# 386543   4.7570
# 386544   4.7570
# 386545   4.7570
# 386546   4.7570
# 386549   4.7570
# 386553   4.7570
# 386555   4.7570
# 386556   4.7570
# 386557   4.7570
# 386562   4.7570
# 386568   4.7570
# 386572   4.7570
# 386663  16.9919
# 386665  16.9919
# 386879  16.9919
# 386885  16.9919
#
# [16536 rows x 19 columns]

# %%
df[df.Other_Race.str.contains("HISP", na=False)].Other_Race.value_counts()
# Out:
# HISPANIC        15728
# HISP              760
# NON HISPANIC       14
# HISPAINC            8
# HISPANCI            5
# HISPAINIC           4
# NONHISPANIC         2
# HISPANICE           2
# HISPANIC.           2
# HISPANC             1
# HISPANIC10          1
# ?HISPANIC           1
# HISPAIN             1
# HISPOANIC           1
# HISPANI             1
# HISPANINC           1
# NON-HISPANIC        1
# HISPANICX           1
# `HISPANIC           1
# HISPANIC1           1
# Name: Other_Race, dtype: int64

# %%
# IS THIS A REGULAR EXPRESSION??????
# yeah!!
df[df.Other_Race.str.contains("^HISP", na=False)].Other_Race.value_counts()
# Out:
# HISPANIC      15728
# HISP            760
# HISPAINC          8
# HISPANCI          5
# HISPAINIC         4
# HISPANIC.         2
# HISPANICE         2
# HISPOANIC         1
# HISPANICX         1
# HISPANINC         1
# HISPANI           1
# HISPAIN           1
# HISPANIC10        1
# HISPANC           1
# HISPANIC1         1
# Name: Other_Race, dtype: int64

# %%
# Replace EXACT values
# df.Other_Race.replace
# ^ the beginning of a line
# .* match ANYTHING
df['Other_Race'] = df.Other_Race.str.replace("^HISP.*", "HISPANIC")
df.Other_Race.value_counts()
# Out:
# HISPANIC           16517
# MULTI-RACIAL        2004
# SOMALI               361
# BIRACIAL              37
# NEPALI                36
# MULTIRACIAL           28
# MULTI RACIAL          24
# NON HISPANIC          14
# ARAB                  13
# PUERTO RICAN          13
# MEXICAN               13
# DECLINE               12
# `                     11
# DO NOT KNOW           11
# UNK                   10
# SPANISH                8
# DECLINED               7
# HISAPNIC               6
# MANDARIN               5
# FULANI                 5
# N/S                    4
# JAPANESE               4
# LAO                    4
# NOT STATED             4
# VIETNAMESE             3
# UK                     3
# ARABIC                 3
# MIXED                  3
# RUSSIAN                3
# HAKHA CHIN             3
#                    ...
# HAWIAN                 1
# - LAC. TO SCALP        1
# URDU                   1
# HYSPANIC/LATINO        1
# HINDI                  1
# `HISPANIC              1
# ``                     1
# MEXICIAN               1
# HIPANIC                1
# TIGRINYA               1
# HIS0PANIC              1
# OTHER RACE UK          1
# AMHARIC                1
# UNKNOKWN               1
# BENGALI                1
# NG                     1
# WHITE/BLACK            1
# ISRAELI                1
# HYPOGLYCEMIA           1
# NON-HISPANIC           1
# UNKOWN                 1
# HS[PANIC               1
# HSIPANIC               1
# CAMBODIAN              1
# HSP                    1
# SOALI                  1
# "                      1
# ?HISPANIC              1
# DONOT KNOW             1
# =                      1
# Name: Other_Race, Length: 84, dtype: int64

# %%
df.Other_Race.head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Other_Race, dtype: object

# %%
df[df.Other_Race == "NaN"]
# Out:
# Empty DataFrame
# Columns: [CPSC_Case_Number, Treatment_Date, Age, Sex, Race, Other_Race, Body_Part, Diagnosis, Other_Diagnosis, Disposition, Location, Fire_Involvement, Product_1, Product_2, Narrative_1, Narrative_2, Stratum, PSU, Weight]
# Index: []
